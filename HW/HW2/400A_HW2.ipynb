# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

f = pd.read_csv('profile1.data', delim_whitespace=True, header=4)
# Out:
# C:\Users\kietb\AppData\Local\Temp\ipykernel_20548\623873425.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   f = pd.read_csv('profile1.data', delim_whitespace=True, header=4)

# %%
f
# Out:
#              mass    radius  luminosity      pressure    logRho      logT  \
# 0    3.000000e-01  9.078884   14.743652  5.536525e+03 -7.635982  3.574764
# 1    3.000000e-01  9.078884   14.743652  5.536535e+03 -7.635981  3.574765
# 2    3.000000e-01  9.078884   14.743651  5.536552e+03 -7.635980  3.574765
# 3    3.000000e-01  9.078884   14.743650  5.536578e+03 -7.635978  3.574765
# 4    3.000000e-01  9.078883   14.743648  5.536623e+03 -7.635975  3.574765
# ..            ...       ...         ...           ...       ...       ...
# 398  3.750094e-07  0.045872    0.000201  2.145085e+11 -2.261822  5.477313
# 399  1.875047e-07  0.036409    0.000112  2.145220e+11 -2.261805  5.477324
# 400  9.375235e-08  0.028897    0.000061  2.145304e+11 -2.261795  5.477330
# 401  4.687618e-08  0.022936    0.000032  2.145358e+11 -2.261789  5.477335
# 402  2.343809e-08  0.018204    0.000016  2.145402e+11 -2.261783  5.477338
#
#            energy    entropy            cp    gamma1  ...        eta  \
# ...

# %%
# My sad attempts to over plot the Polytropic Equation of State
logG = np.log(f['gamma1'])
kappa = 0.3
logKappa = np.log10(kappa) * np.ones_like(logG)
plt.title('Polytropic Equation of State?????')
plt.plot(logG, logKappa)
plt.show()

# %%
f['logP'] = np.log10(f['pressure'])
plt.plot(f['logRho'], f['logP'])
plt.xlabel('Log Density')
plt.ylabel('Log Pressure')
plt.title('P(Rho) Profile')
plt.show()
